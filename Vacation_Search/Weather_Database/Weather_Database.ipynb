# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 743

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + "546afee4bb6b9ceafe0a10b6bb987bd9"
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=546afee4bb6b9ceafe0a10b6bb987bd9

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 2 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | yingcheng
# Processing Record 5 of Set 1 | kamaishi
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | pangoa
# Processing Record 8 of Set 1 | naze
# Processing Record 9 of Set 1 | avarua
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | walvis bay
# Processing Record 12 of Set 1 | yining
# Processing Record 13 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 1 | manggar
# Processing Record 15 of Set 1 | kapaa
# Processing Record 16 of Set 1 | solnechnyy
# Processing Record 17 of Set 1 | jacareacanga
# Processing Record 18 of Set 1 | port elizabeth
# Processing Record 19 of Set 1 | namibe
# Processing Record 20 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 1 | provideniya
# Processing Record 22 of Set 1 | ostrovnoy
# Processing Record 23 of Set 1 | changli
# Processing Record 24 of Set 1 | tafo
# Processing Record 25 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 1 | suba
# Processing Record 27 of Set 1 | quatre cocos
# Processing Record 28 of Set 1 | djambala
# Processing Record 29 of Set 1 | bauchi
# Processing Record 30 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 1 | port hawkesbury
# Processing Record 32 of Set 1 | katsuura
# Processing Record 33 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 1 | yellowknife
# Processing Record 35 of Set 1 | esperance
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | lebu
# Processing Record 38 of Set 1 | bronnoysund
# Processing Record 39 of Set 1 | torbay
# Processing Record 40 of Set 1 | hermanus
# Processing Record 41 of Set 1 | saint-philippe
# Processing Record 42 of Set 1 | mehamn
# Processing Record 43 of Set 1 | punta arenas
# Processing Record 44 of Set 1 | pisco
# Processing Record 45 of Set 1 | boden
# Processing Record 46 of Set 1 | kalanguy
# Processing Record 47 of Set 1 | mentok
# City not found. Skipping...
# Processing Record 48 of Set 1 | bluff
# Processing Record 49 of Set 1 | east london
# Processing Record 50 of Set 1 | clyde river
# Processing Record 1 of Set 2 | port alfred
# Processing Record 2 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 2 | vaini
# Processing Record 4 of Set 2 | hilo
# Processing Record 5 of Set 2 | mandera
# Processing Record 6 of Set 2 | autun
# Processing Record 7 of Set 2 | barrow
# Processing Record 8 of Set 2 | savyntsi
# Processing Record 9 of Set 2 | rio grande
# Processing Record 10 of Set 2 | chuy
# Processing Record 11 of Set 2 | virginia beach
# Processing Record 12 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 2 | bathsheba
# Processing Record 14 of Set 2 | bilibino
# Processing Record 15 of Set 2 | albany
# Processing Record 16 of Set 2 | rauma
# Processing Record 17 of Set 2 | richards bay
# Processing Record 18 of Set 2 | jamestown
# Processing Record 19 of Set 2 | baturaja
# Processing Record 20 of Set 2 | ancud
# Processing Record 21 of Set 2 | tasiilaq
# Processing Record 22 of Set 2 | karratha
# Processing Record 23 of Set 2 | castro
# Processing Record 24 of Set 2 | cherskiy
# Processing Record 25 of Set 2 | dunedin
# Processing Record 26 of Set 2 | airai
# Processing Record 27 of Set 2 | soloneshnoye
# Processing Record 28 of Set 2 | isangel
# Processing Record 29 of Set 2 | skalistyy
# City not found. Skipping...
# Processing Record 30 of Set 2 | rafraf
# Processing Record 31 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 2 | sawtell
# Processing Record 34 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 2 | kruisfontein
# Processing Record 36 of Set 2 | new norfolk
# Processing Record 37 of Set 2 | angra
# City not found. Skipping...
# Processing Record 38 of Set 2 | rikitea
# Processing Record 39 of Set 2 | atuona
# Processing Record 40 of Set 2 | savonlinna
# Processing Record 41 of Set 2 | butaritari
# Processing Record 42 of Set 2 | zaykovo
# Processing Record 43 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 2 | namtsy
# Processing Record 45 of Set 2 | vieste
# Processing Record 46 of Set 2 | kaitangata
# Processing Record 47 of Set 2 | presidencia roque saenz pena
# Processing Record 48 of Set 2 | penzance
# Processing Record 49 of Set 2 | barcelos
# Processing Record 50 of Set 2 | leningradskiy
# Processing Record 1 of Set 3 | cape town
# Processing Record 2 of Set 3 | apomu
# Processing Record 3 of Set 3 | xichang
# Processing Record 4 of Set 3 | winneba
# Processing Record 5 of Set 3 | batemans bay
# Processing Record 6 of Set 3 | masuri
# Processing Record 7 of Set 3 | coihaique
# Processing Record 8 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 9 of Set 3 | olafsvik
# Processing Record 10 of Set 3 | san quintin
# Processing Record 11 of Set 3 | souillac
# Processing Record 12 of Set 3 | yulara
# Processing Record 13 of Set 3 | valparaiso
# Processing Record 14 of Set 3 | paka
# Processing Record 15 of Set 3 | tiarei
# Processing Record 16 of Set 3 | yar-sale
# Processing Record 17 of Set 3 | goderich
# Processing Record 18 of Set 3 | votkinsk
# Processing Record 19 of Set 3 | avdon
# Processing Record 20 of Set 3 | margate
# Processing Record 21 of Set 3 | georgetown
# Processing Record 22 of Set 3 | makakilo city
# Processing Record 23 of Set 3 | buala
# Processing Record 24 of Set 3 | wuwei
# Processing Record 25 of Set 3 | thompson
# Processing Record 26 of Set 3 | terenos
# Processing Record 27 of Set 3 | loughrea
# Processing Record 28 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 29 of Set 3 | mahibadhoo
# Processing Record 30 of Set 3 | khatanga
# Processing Record 31 of Set 3 | teguise
# Processing Record 32 of Set 3 | dikson
# Processing Record 33 of Set 3 | tuggurt
# City not found. Skipping...
# Processing Record 34 of Set 3 | guerrero negro
# Processing Record 35 of Set 3 | nikolskoye
# Processing Record 36 of Set 3 | mayo
# Processing Record 37 of Set 3 | tapes
# Processing Record 38 of Set 3 | liuzhou
# Processing Record 39 of Set 3 | itupiranga
# Processing Record 40 of Set 3 | talnakh
# Processing Record 41 of Set 3 | saint george
# Processing Record 42 of Set 3 | saint-joseph
# Processing Record 43 of Set 3 | sistranda
# Processing Record 44 of Set 3 | rocha
# Processing Record 45 of Set 3 | north myrtle beach
# Processing Record 46 of Set 3 | zhigansk
# Processing Record 47 of Set 3 | balikpapan
# Processing Record 48 of Set 3 | progreso
# Processing Record 49 of Set 3 | rovaniemi
# Processing Record 50 of Set 3 | ngunguru
# Processing Record 1 of Set 4 | narsaq
# Processing Record 2 of Set 4 | fereydun kenar
# Processing Record 3 of Set 4 | vila velha
# Processing Record 4 of Set 4 | yatou
# Processing Record 5 of Set 4 | kodiak
# Processing Record 6 of Set 4 | lavrentiya
# Processing Record 7 of Set 4 | te anau
# Processing Record 8 of Set 4 | houma
# Processing Record 9 of Set 4 | shitkino
# Processing Record 10 of Set 4 | chapais
# Processing Record 11 of Set 4 | yerbogachen
# Processing Record 12 of Set 4 | marzuq
# Processing Record 13 of Set 4 | madona
# Processing Record 14 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 4 | taoudenni
# Processing Record 16 of Set 4 | vostok
# Processing Record 17 of Set 4 | el badari
# City not found. Skipping...
# Processing Record 18 of Set 4 | kavieng
# Processing Record 19 of Set 4 | kapoeta
# Processing Record 20 of Set 4 | norman wells
# Processing Record 21 of Set 4 | hasaki
# Processing Record 22 of Set 4 | santa cruz de la palma
# Processing Record 23 of Set 4 | zhanaozen
# Processing Record 24 of Set 4 | azimur
# City not found. Skipping...
# Processing Record 25 of Set 4 | ilulissat
# Processing Record 26 of Set 4 | hobart
# Processing Record 27 of Set 4 | puerto ayacucho
# Processing Record 28 of Set 4 | krasnyy yar
# Processing Record 29 of Set 4 | pacific grove
# Processing Record 30 of Set 4 | broken hill
# Processing Record 31 of Set 4 | abonnema
# Processing Record 32 of Set 4 | hovd
# Processing Record 33 of Set 4 | ugoofaaru
# Processing Record 34 of Set 4 | hakvik
# City not found. Skipping...
# Processing Record 35 of Set 4 | gushikawa
# Processing Record 36 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 4 | sarkand
# Processing Record 38 of Set 4 | bethel
# Processing Record 39 of Set 4 | longyearbyen
# Processing Record 40 of Set 4 | tuy hoa
# Processing Record 41 of Set 4 | sabha
# Processing Record 42 of Set 4 | saskylakh
# Processing Record 43 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 4 | miri
# Processing Record 45 of Set 4 | sorong
# Processing Record 46 of Set 4 | arbuzynka
# Processing Record 47 of Set 4 | carnarvon
# Processing Record 48 of Set 4 | abapo
# Processing Record 49 of Set 4 | cayenne
# Processing Record 50 of Set 4 | providencia
# Processing Record 1 of Set 5 | hay river
# Processing Record 2 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 3 of Set 5 | jian
# Processing Record 4 of Set 5 | ashqelon
# Processing Record 5 of Set 5 | barreirinhas
# Processing Record 6 of Set 5 | belmonte
# Processing Record 7 of Set 5 | tuktoyaktuk
# Processing Record 8 of Set 5 | alta floresta
# Processing Record 9 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 5 | aripuana
# Processing Record 11 of Set 5 | garoua
# Processing Record 12 of Set 5 | black river
# Processing Record 13 of Set 5 | faya
# Processing Record 14 of Set 5 | iqaluit
# Processing Record 15 of Set 5 | altamira
# Processing Record 16 of Set 5 | alugan
# Processing Record 17 of Set 5 | hofn
# Processing Record 18 of Set 5 | eldikan
# City not found. Skipping...
# Processing Record 19 of Set 5 | faanui
# Processing Record 20 of Set 5 | bekovo
# Processing Record 21 of Set 5 | anadyr
# Processing Record 22 of Set 5 | vardo
# Processing Record 23 of Set 5 | ahipara
# Processing Record 24 of Set 5 | pitimbu
# Processing Record 25 of Set 5 | turukhansk
# Processing Record 26 of Set 5 | vao
# Processing Record 27 of Set 5 | svoronos
# Processing Record 28 of Set 5 | mahebourg
# Processing Record 29 of Set 5 | bambanglipuro
# Processing Record 30 of Set 5 | challapata
# Processing Record 31 of Set 5 | abatskoye
# Processing Record 32 of Set 5 | hithadhoo
# Processing Record 33 of Set 5 | qaanaaq
# Processing Record 34 of Set 5 | salalah
# Processing Record 35 of Set 5 | tiksi
# Processing Record 36 of Set 5 | buraydah
# Processing Record 37 of Set 5 | beloha
# Processing Record 38 of Set 5 | grande-riviere
# City not found. Skipping...
# Processing Record 39 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 40 of Set 5 | stokmarknes
# Processing Record 41 of Set 5 | sydney
# Processing Record 42 of Set 5 | ewa beach
# Processing Record 43 of Set 5 | touros
# Processing Record 44 of Set 5 | buqayq
# City not found. Skipping...
# Processing Record 45 of Set 5 | cabo san lucas
# Processing Record 46 of Set 5 | eureka
# Processing Record 47 of Set 5 | tautira
# Processing Record 48 of Set 5 | north battleford
# Processing Record 49 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 50 of Set 5 | necochea
# Processing Record 1 of Set 6 | oshawa
# Processing Record 2 of Set 6 | strezhevoy
# Processing Record 3 of Set 6 | juneau
# Processing Record 4 of Set 6 | bonthe
# Processing Record 5 of Set 6 | bossembele
# City not found. Skipping...
# Processing Record 6 of Set 6 | bambous virieux
# Processing Record 7 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 6 | trat
# Processing Record 9 of Set 6 | khanpur
# Processing Record 10 of Set 6 | rawson
# Processing Record 11 of Set 6 | vestmannaeyjar
# Processing Record 12 of Set 6 | odweyne
# Processing Record 13 of Set 6 | broome
# Processing Record 14 of Set 6 | dzhebariki-khaya
# Processing Record 15 of Set 6 | terney
# Processing Record 16 of Set 6 | geraldton
# Processing Record 17 of Set 6 | kabompo
# Processing Record 18 of Set 6 | ewo
# Processing Record 19 of Set 6 | french harbor
# Processing Record 20 of Set 6 | upala
# Processing Record 21 of Set 6 | aleysk
# Processing Record 22 of Set 6 | mergui
# City not found. Skipping...
# Processing Record 23 of Set 6 | ribeira grande
# Processing Record 24 of Set 6 | pozo colorado
# Processing Record 25 of Set 6 | bingol
# Processing Record 26 of Set 6 | cidreira
# Processing Record 27 of Set 6 | miquelon
# Processing Record 28 of Set 6 | lincoln
# Processing Record 29 of Set 6 | porto novo
# Processing Record 30 of Set 6 | mnogovershinnyy
# Processing Record 31 of Set 6 | wanlaweyn
# Processing Record 32 of Set 6 | lichinga
# Processing Record 33 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 34 of Set 6 | sechura
# Processing Record 35 of Set 6 | saldanha
# Processing Record 36 of Set 6 | gamba
# Processing Record 37 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 38 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 39 of Set 6 | grindavik
# Processing Record 40 of Set 6 | kahului
# Processing Record 41 of Set 6 | sugag
# Processing Record 42 of Set 6 | calbuco
# Processing Record 43 of Set 6 | taree
# Processing Record 44 of Set 6 | vigrestad
# Processing Record 45 of Set 6 | hangal
# Processing Record 46 of Set 6 | mazagao
# Processing Record 47 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 48 of Set 6 | burnie
# Processing Record 49 of Set 6 | san pedro de uraba
# Processing Record 50 of Set 6 | turkmenabat
# Processing Record 1 of Set 7 | lagoa
# Processing Record 2 of Set 7 | arraial do cabo
# Processing Record 3 of Set 7 | athabasca
# Processing Record 4 of Set 7 | bengkulu
# Processing Record 5 of Set 7 | mollendo
# Processing Record 6 of Set 7 | corowa
# Processing Record 7 of Set 7 | codrington
# Processing Record 8 of Set 7 | emilio carranza
# Processing Record 9 of Set 7 | portland
# Processing Record 10 of Set 7 | ponta do sol
# Processing Record 11 of Set 7 | altay
# Processing Record 12 of Set 7 | almaznyy
# Processing Record 13 of Set 7 | ercis
# Processing Record 14 of Set 7 | chokurdakh
# Processing Record 15 of Set 7 | krupanj
# Processing Record 16 of Set 7 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 17 of Set 7 | mar del plata
# Processing Record 18 of Set 7 | lompoc
# Processing Record 19 of Set 7 | nalut
# Processing Record 20 of Set 7 | ribnica
# Processing Record 21 of Set 7 | tubuala
# Processing Record 22 of Set 7 | boguchany
# Processing Record 23 of Set 7 | luba
# Processing Record 24 of Set 7 | ville-marie
# Processing Record 25 of Set 7 | dianopolis
# City not found. Skipping...
# Processing Record 26 of Set 7 | nuuk
# Processing Record 27 of Set 7 | ponta delgada
# Processing Record 28 of Set 7 | kiruna
# Processing Record 29 of Set 7 | granja
# Processing Record 30 of Set 7 | luau
# Processing Record 31 of Set 7 | porto santo
# Processing Record 32 of Set 7 | achacachi
# Processing Record 33 of Set 7 | kenai
# Processing Record 34 of Set 7 | hambantota
# Processing Record 35 of Set 7 | zaysan
# Processing Record 36 of Set 7 | visnes
# Processing Record 37 of Set 7 | smithers
# Processing Record 38 of Set 7 | sitka
# Processing Record 39 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 40 of Set 7 | severo-kurilsk
# Processing Record 41 of Set 7 | tubruq
# City not found. Skipping...
# Processing Record 42 of Set 7 | lunino
# Processing Record 43 of Set 7 | boende
# Processing Record 44 of Set 7 | camabatela
# Processing Record 45 of Set 7 | calvinia
# Processing Record 46 of Set 7 | sai buri
# Processing Record 47 of Set 7 | saint anthony
# Processing Record 48 of Set 7 | nioro
# Processing Record 49 of Set 7 | mednogorsk
# Processing Record 50 of Set 7 | puri
# Processing Record 1 of Set 8 | bakchar
# Processing Record 2 of Set 8 | bonavista
# Processing Record 3 of Set 8 | naini tal
# Processing Record 4 of Set 8 | seoul
# Processing Record 5 of Set 8 | pevek
# Processing Record 6 of Set 8 | brae
# Processing Record 7 of Set 8 | saint-pierre
# Processing Record 8 of Set 8 | moscow
# Processing Record 9 of Set 8 | dharmapuri
# Processing Record 10 of Set 8 | port blair
# Processing Record 11 of Set 8 | tambura
# Processing Record 12 of Set 8 | senador pompeu
# Processing Record 13 of Set 8 | makungu
# Processing Record 14 of Set 8 | ridgecrest
# Processing Record 15 of Set 8 | ibra
# Processing Record 16 of Set 8 | lephepe
# City not found. Skipping...
# Processing Record 17 of Set 8 | mahadday weyne
# City not found. Skipping...
# Processing Record 18 of Set 8 | meulaboh
# Processing Record 19 of Set 8 | kontagora
# Processing Record 20 of Set 8 | sangar
# Processing Record 21 of Set 8 | amapa
# Processing Record 22 of Set 8 | kadhan
# Processing Record 23 of Set 8 | lorengau
# Processing Record 24 of Set 8 | thinadhoo
# Processing Record 25 of Set 8 | marolambo
# Processing Record 26 of Set 8 | opuwo
# Processing Record 27 of Set 8 | jashpurnagar
# Processing Record 28 of Set 8 | atambua
# Processing Record 29 of Set 8 | isiro
# Processing Record 30 of Set 8 | port lincoln
# Processing Record 31 of Set 8 | ronne
# Processing Record 32 of Set 8 | sao filipe
# Processing Record 33 of Set 8 | upernavik
# Processing Record 34 of Set 8 | laguna
# Processing Record 35 of Set 8 | gimli
# Processing Record 36 of Set 8 | luanda
# Processing Record 37 of Set 8 | nemuro
# Processing Record 38 of Set 8 | beringovskiy
# Processing Record 39 of Set 8 | komsomolskiy
# Processing Record 40 of Set 8 | lashio
# Processing Record 41 of Set 8 | najran
# Processing Record 42 of Set 8 | alofi
# Processing Record 43 of Set 8 | general roca
# Processing Record 44 of Set 8 | repedea
# Processing Record 45 of Set 8 | srednekolymsk
# Processing Record 46 of Set 8 | reo
# Processing Record 47 of Set 8 | price
# Processing Record 48 of Set 8 | linguere
# Processing Record 49 of Set 8 | nanortalik
# Processing Record 50 of Set 8 | onega
# Processing Record 1 of Set 9 | teya
# Processing Record 2 of Set 9 | sao desiderio
# Processing Record 3 of Set 9 | melo
# Processing Record 4 of Set 9 | khon kaen
# Processing Record 5 of Set 9 | ciras
# City not found. Skipping...
# Processing Record 6 of Set 9 | harrison
# Processing Record 7 of Set 9 | cibitung
# Processing Record 8 of Set 9 | balancan
# Processing Record 9 of Set 9 | imeni babushkina
# Processing Record 10 of Set 9 | buriti dos lopes
# Processing Record 11 of Set 9 | manta
# Processing Record 12 of Set 9 | makrakomi
# Processing Record 13 of Set 9 | southbridge
# Processing Record 14 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 15 of Set 9 | ust-nera
# Processing Record 16 of Set 9 | shangzhi
# Processing Record 17 of Set 9 | severo-yeniseyskiy
# Processing Record 18 of Set 9 | blagoyevo
# Processing Record 19 of Set 9 | mandalgovi
# Processing Record 20 of Set 9 | davlekanovo
# Processing Record 21 of Set 9 | bandarbeyla
# Processing Record 22 of Set 9 | moose factory
# Processing Record 23 of Set 9 | fortuna
# Processing Record 24 of Set 9 | haag
# Processing Record 25 of Set 9 | kikwit
# Processing Record 26 of Set 9 | bako
# Processing Record 27 of Set 9 | port hedland
# Processing Record 28 of Set 9 | kotlas
# Processing Record 29 of Set 9 | budingen
# Processing Record 30 of Set 9 | erenhot
# Processing Record 31 of Set 9 | tuatapere
# Processing Record 32 of Set 9 | orange
# Processing Record 33 of Set 9 | san patricio
# Processing Record 34 of Set 9 | aklavik
# Processing Record 35 of Set 9 | manbij
# Processing Record 36 of Set 9 | vanimo
# Processing Record 37 of Set 9 | shimoda
# Processing Record 38 of Set 9 | constitucion
# Processing Record 39 of Set 9 | zambezi
# Processing Record 40 of Set 9 | elliot lake
# Processing Record 41 of Set 9 | ahtopol
# Processing Record 42 of Set 9 | talcahuano
# Processing Record 43 of Set 9 | jefferson city
# Processing Record 44 of Set 9 | klaksvik
# Processing Record 45 of Set 9 | camacha
# Processing Record 46 of Set 9 | victoria
# Processing Record 47 of Set 9 | riyadh
# Processing Record 48 of Set 9 | ginir
# Processing Record 49 of Set 9 | estelle
# Processing Record 50 of Set 9 | sao gabriel da cachoeira
# Processing Record 1 of Set 10 | quixada
# Processing Record 2 of Set 10 | san francisco
# Processing Record 3 of Set 10 | whitehorse
# Processing Record 4 of Set 10 | tadine
# Processing Record 5 of Set 10 | coffs harbour
# Processing Record 6 of Set 10 | roald
# Processing Record 7 of Set 10 | soure
# Processing Record 8 of Set 10 | hobyo
# Processing Record 9 of Set 10 | rajanpur
# Processing Record 10 of Set 10 | mount isa
# Processing Record 11 of Set 10 | pafos
# Processing Record 12 of Set 10 | brewster
# Processing Record 13 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 14 of Set 10 | gizo
# Processing Record 15 of Set 10 | patu
# Processing Record 16 of Set 10 | loikaw
# Processing Record 17 of Set 10 | lakatoro
# Processing Record 18 of Set 10 | parauna
# Processing Record 19 of Set 10 | aksu
# Processing Record 20 of Set 10 | phonhong
# Processing Record 21 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 10 | leninskoye
# Processing Record 23 of Set 10 | asau
# Processing Record 24 of Set 10 | tabat
# Processing Record 25 of Set 10 | portpatrick
# City not found. Skipping...
# Processing Record 26 of Set 10 | pak phanang
# Processing Record 27 of Set 10 | nouadhibou
# Processing Record 28 of Set 10 | itarema
# Processing Record 29 of Set 10 | pingchen
# City not found. Skipping...
# Processing Record 30 of Set 10 | moiyabana
# City not found. Skipping...
# Processing Record 31 of Set 10 | zhicheng
# Processing Record 32 of Set 10 | havoysund
# Processing Record 33 of Set 10 | port-cartier
# Processing Record 34 of Set 10 | sorumsand
# Processing Record 35 of Set 10 | bacungan
# Processing Record 36 of Set 10 | dingle
# Processing Record 37 of Set 10 | dzhubga
# Processing Record 38 of Set 10 | mezen
# Processing Record 39 of Set 10 | coquimbo
# Processing Record 40 of Set 10 | daru
# Processing Record 41 of Set 10 | hun
# Processing Record 42 of Set 10 | xining
# Processing Record 43 of Set 10 | sinnamary
# Processing Record 44 of Set 10 | sao joao da barra
# Processing Record 45 of Set 10 | avera
# Processing Record 46 of Set 10 | cintalapa
# Processing Record 47 of Set 10 | busembatia
# Processing Record 48 of Set 10 | jalu
# Processing Record 49 of Set 10 | balkanabat
# Processing Record 50 of Set 10 | naranjal
# Processing Record 1 of Set 11 | vetluzhskiy
# Processing Record 2 of Set 11 | bogatyye saby
# Processing Record 3 of Set 11 | san ramon
# Processing Record 4 of Set 11 | mount gambier
# Processing Record 5 of Set 11 | sanmenxia
# Processing Record 6 of Set 11 | klyuchi
# Processing Record 7 of Set 11 | carutapera
# Processing Record 8 of Set 11 | shar
# Processing Record 9 of Set 11 | big spring
# Processing Record 10 of Set 11 | noumea
# Processing Record 11 of Set 11 | tomatlan
# Processing Record 12 of Set 11 | bonnyville
# Processing Record 13 of Set 11 | marawi
# Processing Record 14 of Set 11 | fairbanks
# Processing Record 15 of Set 11 | kytlym
# City not found. Skipping...
# Processing Record 16 of Set 11 | collie
# Processing Record 17 of Set 11 | barkot
# Processing Record 18 of Set 11 | belyy yar
# Processing Record 19 of Set 11 | gornopravdinsk
# Processing Record 20 of Set 11 | chaozhou
# Processing Record 21 of Set 11 | saquarema
# Processing Record 22 of Set 11 | phrai bung
# City not found. Skipping...
# Processing Record 23 of Set 11 | enterprise
# Processing Record 24 of Set 11 | port moresby
# Processing Record 25 of Set 11 | alyangula
# Processing Record 26 of Set 11 | kula
# Processing Record 27 of Set 11 | bar-le-duc
# Processing Record 28 of Set 11 | grong
# Processing Record 29 of Set 11 | vila franca do campo
# Processing Record 30 of Set 11 | salina cruz
# Processing Record 31 of Set 11 | dongsheng
# Processing Record 32 of Set 11 | la merced
# Processing Record 33 of Set 11 | tawnat
# City not found. Skipping...
# Processing Record 34 of Set 11 | tucuman
# Processing Record 35 of Set 11 | afyonkarahisar
# Processing Record 36 of Set 11 | port hardy
# Processing Record 37 of Set 11 | namestovo
# Processing Record 38 of Set 11 | amot
# Processing Record 39 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 11 | argayash
# Processing Record 41 of Set 11 | tromso
# Processing Record 42 of Set 11 | gorontalo
# Processing Record 43 of Set 11 | sendafa
# Processing Record 44 of Set 11 | padang
# Processing Record 45 of Set 11 | westport
# Processing Record 46 of Set 11 | haifa
# Processing Record 47 of Set 11 | puerto escondido
# Processing Record 48 of Set 11 | pandan
# Processing Record 49 of Set 11 | malaryta
# Processing Record 50 of Set 11 | labuhan
# Processing Record 1 of Set 12 | tilichiki
# Processing Record 2 of Set 12 | wilmington
# Processing Record 3 of Set 12 | sandakan
# Processing Record 4 of Set 12 | miles city
# Processing Record 5 of Set 12 | brooks
# Processing Record 6 of Set 12 | lerwick
# Processing Record 7 of Set 12 | rondonopolis
# Processing Record 8 of Set 12 | pringsewu
# Processing Record 9 of Set 12 | rudbar
# Processing Record 10 of Set 12 | srivardhan
# Processing Record 11 of Set 12 | santa marta
# Processing Record 12 of Set 12 | banjar
# Processing Record 13 of Set 12 | matadi
# Processing Record 14 of Set 12 | gondanglegi
# Processing Record 15 of Set 12 | afmadu
# City not found. Skipping...
# Processing Record 16 of Set 12 | luderitz
# Processing Record 17 of Set 12 | north platte
# Processing Record 18 of Set 12 | sandnessjoen
# Processing Record 19 of Set 12 | balimo
# City not found. Skipping...
# Processing Record 20 of Set 12 | coahuayana
# Processing Record 21 of Set 12 | marsa matruh
# Processing Record 22 of Set 12 | kulhudhuffushi
# Processing Record 23 of Set 12 | naron
# Processing Record 24 of Set 12 | umm kaddadah
# Processing Record 25 of Set 12 | tabarqah
# City not found. Skipping...
# Processing Record 26 of Set 12 | olinda
# Processing Record 27 of Set 12 | sao miguel do araguaia
# Processing Record 28 of Set 12 | bridgetown
# Processing Record 29 of Set 12 | levelland
# Processing Record 30 of Set 12 | mazara del vallo
# Processing Record 31 of Set 12 | vylkove
# Processing Record 32 of Set 12 | onoda
# Processing Record 33 of Set 12 | malakwal
# Processing Record 34 of Set 12 | mitu
# Processing Record 35 of Set 12 | ushtobe
# Processing Record 36 of Set 12 | monte cristi
# City not found. Skipping...
# Processing Record 37 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 38 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 39 of Set 12 | moroni
# Processing Record 40 of Set 12 | arua
# Processing Record 41 of Set 12 | awjilah
# Processing Record 42 of Set 12 | hunza
# City not found. Skipping...
# Processing Record 43 of Set 12 | praia da vitoria
# Processing Record 44 of Set 12 | cabatuan
# Processing Record 45 of Set 12 | garcia hernandez
# Processing Record 46 of Set 12 | husavik
# Processing Record 47 of Set 12 | dharchula
# Processing Record 48 of Set 12 | hudson bay
# Processing Record 49 of Set 12 | abu samrah
# Processing Record 50 of Set 12 | maniitsoq
# Processing Record 1 of Set 13 | malia
# Processing Record 2 of Set 13 | zaranj
# Processing Record 3 of Set 13 | at-bashi
# Processing Record 4 of Set 13 | kavaratti
# Processing Record 5 of Set 13 | bardsir
# Processing Record 6 of Set 13 | lebedinyy
# Processing Record 7 of Set 13 | shache
# Processing Record 8 of Set 13 | banepa
# Processing Record 9 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 10 of Set 13 | korla
# Processing Record 11 of Set 13 | sainte-maxime
# Processing Record 12 of Set 13 | cheyenne
# Processing Record 13 of Set 13 | reconquista
# Processing Record 14 of Set 13 | barra patuca
# Processing Record 15 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 16 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 17 of Set 13 | adrar
# Processing Record 18 of Set 13 | pierre
# Processing Record 19 of Set 13 | chimore
# Processing Record 20 of Set 13 | ruwi
# Processing Record 21 of Set 13 | itoman
# Processing Record 22 of Set 13 | carhuaz
# Processing Record 23 of Set 13 | kongolo
# Processing Record 24 of Set 13 | inirida
# Processing Record 25 of Set 13 | svetlogorsk
# Processing Record 26 of Set 13 | murray bridge
# Processing Record 27 of Set 13 | turiacu
# Processing Record 28 of Set 13 | oistins
# Processing Record 29 of Set 13 | artesia
# Processing Record 30 of Set 13 | oum hadjer
# Processing Record 31 of Set 13 | bartow
# Processing Record 32 of Set 13 | ola
# Processing Record 33 of Set 13 | mbuji-mayi
# Processing Record 34 of Set 13 | kanchanaburi
# Processing Record 35 of Set 13 | yeppoon
# Processing Record 36 of Set 13 | moindou
# Processing Record 37 of Set 13 | gap
# Processing Record 38 of Set 13 | vung tau
# Processing Record 39 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 13 | starokostyantyniv
# Processing Record 41 of Set 13 | lasa
# Processing Record 42 of Set 13 | grand gaube
# Processing Record 43 of Set 13 | gladstone
# Processing Record 44 of Set 13 | urdzhar
# City not found. Skipping...
# Processing Record 45 of Set 13 | hamada
# Processing Record 46 of Set 13 | lodja
# Processing Record 47 of Set 13 | chinhoyi
# Processing Record 48 of Set 13 | verkhoyansk
# Processing Record 49 of Set 13 | tornio
# Processing Record 50 of Set 13 | araouane
# Processing Record 1 of Set 14 | hualmay
# Processing Record 2 of Set 14 | songjianghe
# Processing Record 3 of Set 14 | nara
# Processing Record 4 of Set 14 | inhambane
# Processing Record 5 of Set 14 | fundacion
# Processing Record 6 of Set 14 | kushmurun
# Processing Record 7 of Set 14 | myingyan
# Processing Record 8 of Set 14 | luganville
# Processing Record 9 of Set 14 | fort nelson
# Processing Record 10 of Set 14 | kamenka
# Processing Record 11 of Set 14 | albury
# Processing Record 12 of Set 14 | mecca
# Processing Record 13 of Set 14 | staraya kulatka
# Processing Record 14 of Set 14 | aneho
# Processing Record 15 of Set 14 | gambela
# Processing Record 16 of Set 14 | pangkalanbuun
# Processing Record 17 of Set 14 | mancio lima
# Processing Record 18 of Set 14 | tamiahua
# Processing Record 19 of Set 14 | male
# Processing Record 20 of Set 14 | barabai
# Processing Record 21 of Set 14 | moorhead
# Processing Record 22 of Set 14 | kaeo
# Processing Record 23 of Set 14 | santa catalina
# Processing Record 24 of Set 14 | sargans
# Processing Record 25 of Set 14 | brigantine
# Processing Record 26 of Set 14 | coruripe
# Processing Record 27 of Set 14 | iwanai
# Processing Record 28 of Set 14 | worthing
# Processing Record 29 of Set 14 | north branch
# Processing Record 30 of Set 14 | khani
# Processing Record 31 of Set 14 | bardiyah
# Processing Record 32 of Set 14 | camacari
# Processing Record 33 of Set 14 | xiaoshi
# Processing Record 34 of Set 14 | urubicha
# Processing Record 35 of Set 14 | montepuez
# Processing Record 36 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 37 of Set 14 | asosa
# Processing Record 38 of Set 14 | gravdal
# Processing Record 39 of Set 14 | yaan
# Processing Record 40 of Set 14 | dracena
# Processing Record 41 of Set 14 | xam nua
# Processing Record 42 of Set 14 | goundam
# Processing Record 43 of Set 14 | nicoya
# Processing Record 44 of Set 14 | atherton
# Processing Record 45 of Set 14 | ottawa
# Processing Record 46 of Set 14 | montijo
# Processing Record 47 of Set 14 | muros
# Processing Record 48 of Set 14 | galeana
# Processing Record 49 of Set 14 | pocinhos
# Processing Record 50 of Set 14 | cairo
# Processing Record 1 of Set 15 | thunder bay
# Processing Record 2 of Set 15 | kautokeino
# Processing Record 3 of Set 15 | rodrigues alves
# Processing Record 4 of Set 15 | toamasina
# Processing Record 5 of Set 15 | qurayyat
# Processing Record 6 of Set 15 | evensk
# Processing Record 7 of Set 15 | aleksandrovskoye
# Processing Record 8 of Set 15 | molteno
# Processing Record 9 of Set 15 | huarmey
# Processing Record 10 of Set 15 | caravelas
# Processing Record 11 of Set 15 | morgan city
# Processing Record 12 of Set 15 | cockburn town
# Processing Record 13 of Set 15 | sobolevo
# Processing Record 14 of Set 15 | vagay
# Processing Record 15 of Set 15 | kilindoni
# Processing Record 16 of Set 15 | la ronge
# Processing Record 17 of Set 15 | shelbyville
# Processing Record 18 of Set 15 | sao francisco de assis
# Processing Record 19 of Set 15 | jizan
# Processing Record 20 of Set 15 | mizpe ramon
# City not found. Skipping...
# Processing Record 21 of Set 15 | kjollefjord
# Processing Record 22 of Set 15 | christchurch
# Processing Record 23 of Set 15 | maloy
# Processing Record 24 of Set 15 | arman
# Processing Record 25 of Set 15 | fuente de oro
# Processing Record 26 of Set 15 | dudinka
# Processing Record 27 of Set 15 | bryan
# Processing Record 28 of Set 15 | biak
# Processing Record 29 of Set 15 | abu dhabi
# Processing Record 30 of Set 15 | pando
# Processing Record 31 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 32 of Set 15 | roma
# Processing Record 33 of Set 15 | nakatunguru
# Processing Record 34 of Set 15 | nabire
# Processing Record 35 of Set 15 | sicamous
# Processing Record 36 of Set 15 | karakendzha
# City not found. Skipping...
# Processing Record 37 of Set 15 | yankton
# Processing Record 38 of Set 15 | ciudad bolivar
# Processing Record 39 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 15 | atbasar
# Processing Record 41 of Set 15 | connersville
# Processing Record 42 of Set 15 | flin flon
# Processing Record 43 of Set 15 | zheleznodorozhnyy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Bredasdorp -34.5322   20.0403     55.27        94         100
# 1       Mataura -46.1927  168.8643     44.47        86         100
# 2     Yingcheng  30.9500  113.5500     91.02        67          40
# 3      Kamaishi  39.2667  141.8833     83.26        75          16
# 4  Puerto Ayora  -0.7393  -90.3518     70.56        92          48
# 5        Pangoa -12.1167  -73.0000     65.35        72          37
# 6          Naze  28.3667  129.4833     80.37        87          85
# 7        Avarua -21.2078 -159.7750     75.25        94          75
# 8       Ushuaia -54.8000  -68.3000     38.86        81          40
# 9    Walvis Bay -22.9575   14.5053     74.35        16           0
#
#    Wind Speed Country Current Description
# 0        3.44      ZA     overcast clouds
# 1        5.86      NZ          light rain
# 2        9.19      CN    scattered clouds
# 3       12.03      JP          few clouds
# 4        4.00      EC    scattered clouds
# 5        2.77      PE    scattered clouds
# 6       17.87      JP          light rain
# 7       10.36      CK          light rain
# 8        6.91      AR    scattered clouds
# 9       18.41      NA           clear sky

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Bredasdorp      ZA -34.5322   20.0403     55.27        94         100
# 1       Mataura      NZ -46.1927  168.8643     44.47        86         100
# 2     Yingcheng      CN  30.9500  113.5500     91.02        67          40
# 3      Kamaishi      JP  39.2667  141.8833     83.26        75          16
# 4  Puerto Ayora      EC  -0.7393  -90.3518     70.56        92          48
# 5        Pangoa      PE -12.1167  -73.0000     65.35        72          37
# 6          Naze      JP  28.3667  129.4833     80.37        87          85
# 7        Avarua      CK -21.2078 -159.7750     75.25        94          75
# 8       Ushuaia      AR -54.8000  -68.3000     38.86        81          40
# 9    Walvis Bay      NA -22.9575   14.5053     74.35        16           0
#
#    Wind Speed Current Description
# 0        3.44     overcast clouds
# 1        5.86          light rain
# 2        9.19    scattered clouds
# 3       12.03          few clouds
# 4        4.00    scattered clouds
# 5        2.77    scattered clouds
# 6       17.87          light rain
# 7       10.36          light rain
# 8        6.91    scattered clouds
# 9       18.41           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
